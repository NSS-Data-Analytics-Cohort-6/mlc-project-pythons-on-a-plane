# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline
mlc_df=pd.read_csv('../data/MLC_Data_Sample.csv')
mlc_df.head()
# Out:
#           ISRC Country Code Registrant Code  Year of Reference Usage Period  \
# 0  1.94923E+11           19             492               33.0     1/1/2021
# 1  1.95757E+11           19             575               70.0     5/1/2021
# 2  8.59716E+11           85             971               57.0     4/1/2021
# 3  8.59716E+11           85             971               57.0     4/1/2021
# 4  8.59717E+11           85             971               67.0     3/1/2021
#
#   Streaming Platform (DSP) Streams Recording Artist   Recording Label  \
# 0                  Spotify  13,620           MARINA  Atlantic Records
# 1                  Pandora  12,160      Chris Webby          EightyHD
# 2                   Amazon   2,451      Parry Gripp       Parry Gripp
# 3                   Amazon   2,451      Parry Gripp       Parry Gripp
# 4                  Spotify  69,876    Pacey Carroll     Pacey Carroll
#
#                    Recording Title                         Release Title  \
# ...

# %%
#First 14 rows are in scientific notation. Looking to see how far down this goes.After running this code, it appears to be with
#earlier years. The latest year for this is 1967 and the earliest is 1933. 
mlc_df.head(15)
# Out:
#             ISRC Country Code Registrant Code  Year of Reference Usage Period  \
# 0    1.94923E+11           19             492               33.0     1/1/2021
# 1    1.95757E+11           19             575               70.0     5/1/2021
# 2    8.59716E+11           85             971               57.0     4/1/2021
# 3    8.59716E+11           85             971               57.0     4/1/2021
# 4    8.59717E+11           85             971               67.0     3/1/2021
# 5    8.59717E+11           85             971               67.0     5/1/2021
# 6    8.59717E+11           85             971               67.0     3/1/2021
# 7    8.59717E+11           85             971               67.0     4/1/2021
# 8    8.59717E+11           85             971               67.0     3/1/2021
# 9    8.59717E+11           85             971               67.0     3/1/2021
# 10   8.59717E+11           85             971               67.0     3/1/2021
# ...

# %%
mlc_df.tail()
# Out:
#       ISRC Country Code Registrant Code  Year of Reference Usage Period  \
# 99995  NaN          NaN             NaN                NaN     3/1/2021
# 99996  NaN          NaN             NaN                NaN     3/1/2021
# 99997  NaN          NaN             NaN                NaN     5/1/2021
# 99998  NaN          NaN             NaN                NaN     3/1/2021
# 99999  NaN          NaN             NaN                NaN     5/1/2021
#
#       Streaming Platform (DSP) Streams Recording Artist  \
# 99995                  Pandora  14,912         Lil Durk
# 99996                   Amazon   1,331    Nipsey Hussle
# 99997                    Apple  19,567            Phora
# 99998                    Apple  47,412         Lil Migo
# 99999                  Pandora   3,206   Seamus Kennedy
#
#                   Recording Label  \
# 99995      Alamo (Geffen Records)
# 99996  Howie McDuffie Music Group
# 99997                   Phora LLC
# 99998             Plug Brudaz Ent
# ...

# %%
mlc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   ISRC                                       98240 non-null   object
#  1   Country Code                               98303 non-null   object
#  2   Registrant Code                            98303 non-null   object
#  3   Year of Reference                          98239 non-null   float64
#  4   Usage Period                               91898 non-null   object
#  5   Streaming Platform (DSP)                   96001 non-null   object
#  6   Streams                                    100000 non-null  object
#  7   Recording Artist                           100000 non-null  object
#  8   Recording Label                            98992 non-null   object
# ...

# %%
#Checking the amount of null values for each column
mlc_df.isnull().sum()
# Out:
# ISRC                                         1760
# Country Code                                 1697
# Registrant Code                              1697
# Year of Reference                            1761
# Usage Period                                 8102
# Streaming Platform (DSP)                     3999
# Streams                                         0
# Recording Artist                                0
# Recording Label                              1008
# Recording Title                                 0
# Release Title                                  69
# Recording Duration (Seconds)                    0
# Songwriter's Listed (1 = "Yes", 0 = "No")       0
# dtype: int64

# %%
mlc_df.describe()
# Out:
#        Year of Reference  Recording Duration (Seconds)  \
# count       98239.000000                 100000.000000
# mean           19.671933                   1016.893690
# std            12.638870                  15565.692133
# min             0.000000                      0.000000
# 25%            17.000000                    149.000000
# 50%            19.000000                    190.000000
# 75%            20.000000                    236.000000
# max            99.000000                 818738.000000
#
#        Songwriter's Listed (1 = "Yes", 0 = "No")
# count                              100000.000000
# mean                                    0.541610
# std                                     0.498268
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     1.000000
# 75%                                     1.000000
# max                                     1.000000

# %%
#Checking on how many rows of our unique column are actually unique
mlc_df.ISRC.nunique()
# Out:
# 54621

# %%
mlc_df['Recording Duration (Seconds)'].max()
# Out:
# 818738

# %%
mlc_df['Recording Duration (Seconds)'].min()
# Out:
# 0

# %% [markdown]
# Recording min and max times seem strange
