# %%
import json
import pandas as pd 
from matplotlib import pyplot as plt

# %%
g = open('../data/genres.json')
genres_json = json.load(g)
genres = pd.DataFrame(dict([(k,pd.Series(v)) for k,v in genres_json.items()]))
genres = pd.melt(genres)
genres = genres.dropna()
genres = genres.reset_index(drop = True)
genres.columns = ['artist', 'genre']
genres.head(20)
# Out:
#                   artist                                              genre
# 0   The Jeff Healey Band                                              Blues
# 1   The Jeff Healey Band                                               rock
# 2   The Jeff Healey Band                                               jazz
# 3     Piotr Anderszewski                                          Classical
# 4          Inigo Pascual                                     Pinoy pop, OPM
# 5              The Juans                                                Pop
# 6              The Juans                                           pop rock
# 7              The Juans                                              indie
# 8              The Juans                                           neo soul
# 9             Cory Marks                                            Country
# 10            Cory Marks                                       country rock
# ...

# %%
genres.columns
# Out:
# Index(['artist', 'genre'], dtype='object')

# %%
genres['genre'].value_counts()
# Out:
# Hip hop                           671
# R&B                               516
# pop                               281
# Pop                               278
# hip hop                           211
#                                  ...
# doom metal (early)                  1
# old-time                            1
# Film score, pop, jazz               1
# Hip hop, West Coast Rap, Hyphy      1
# Folk, R&B                           1
# Name: genre, Length: 2135, dtype: int64

# %%
genres_subset = genres[['genre']]
genres_subset
# Out:
#                 genre
# 0               Blues
# 1                rock
# 2                jazz
# 3           Classical
# 4      Pinoy pop, OPM
# ...               ...
# 11061       Reggaeton
# 11062          urbano
# 11063         Hip hop
# 11064             R&B
# 11065        Neo soul
#
# [11066 rows x 1 columns]

# %%
genres.isna().sum()
# Out:
# artist    0
# genre     0
# dtype: int64

# %%
genres.describe()
# Out:
#            artist    genre
# count       11066    11066
# unique       4248     2135
# top     Tom Misch  Hip hop
# freq           13      671

# %%
genres.dtypes
# Out:
# artist    object
# genre     object
# dtype: object

# %%
genres.apply(pd.Series.value_counts)
# Out:
#                      artist  genre
#                         NaN    3.0
#  Hip hop                NaN    2.0
#  classical              NaN    1.0
#  middle of the road     NaN    1.0
#  outlaw country         NaN    1.0
# ...                     ...    ...
# Земфира                 1.0    NaN
# ミラクルミュージカル              6.0    NaN
# ヨルシカ                    4.0    NaN
# 周深                      1.0    NaN
# ２８１４                    3.0    NaN
#
# [6383 rows x 2 columns]

# %%
genres.groupby('genre').describe()
# Out:
#                     artist
#                      count unique                   top freq
# genre
#                          3      3         Circa Survive    1
#  Hip hop                 2      2  Bone Thugs N Harmony    1
#  classical               1      1    Dimash Qudaibergen    1
#  middle of the road      1      1          Clean Bandit    1
#  outlaw country          1      1           Johnny Cash    1
# ...                    ...    ...                   ...  ...
# world music              5      5          A. R. Rahman    1
# worldbeat                3      3         Talking Heads    1
# worship                  5      5         Juanita Bynum    1
# worship music            1      1       Aaron Gillespie    1
# yé-yé                    1      1       Johnny Hallyday    1
#
# [2135 rows x 4 columns]

# %%
sample_data = pd.read_csv("../data/Matching Sample for NSS (100k Lines).xlsx - MLC Data Sample.csv")
sample_data = sample_data.dropna()
sample_data = sample_data.reset_index(drop = True)
sample_data.head(20)
# Out:
#              If  Country Code Registrant Code  Year of Reference Usage Period  \
# 0   USLD91731547           US             LD9               17.0     2/1/2021
# 1   QZJ842000983           QZ             J84               20.0     3/1/2021
# 2   USUG12100126           US             UG1               21.0     3/1/2021
# 3   QMJMT2103634           QM             JMT               21.0     2/1/2021
# 4   USRC12100543           US             RC1               21.0     3/1/2021
# 5   USAT22007048           US             AT2               20.0     3/1/2021
# 6   USLD91730830           US             LD9               17.0     3/1/2021
# 7   QMCE32100237           QM             CE3               21.0     1/1/2021
# 8   USAT22100145           US             AT2               21.0     5/1/2021
# 9   USUM72102809           US             UM7               21.0     1/1/2021
# 10  USUM72102809           US             UM7               21.0     5/1/2021
# ...

# %%
type(sample_data)
# Out:
# pandas.core.frame.DataFrame

# %%
sample_data['Streams'].value_counts()
# Out:
#   1           863
#   6            85
#   5            84
#   3            67
#   4            65
#              ...
#   25,174        1
#   23,637        1
#   629,419       1
#   324,928       1
#   3,733         1
# Name: Streams, Length: 48098, dtype: int64

# %%
sample_data.apply(pd.Series.value_counts)
# Out:
#                           If   Country Code  Registrant Code  \
# 0.0                       NaN           NaN              NaN
# 1.0                       NaN           NaN              NaN
# 2.0                       NaN           NaN              NaN
# 3.0                       NaN           NaN              NaN
# 4.0                       NaN           NaN              NaN
# ...                       ...           ...              ...
# 흥폭발' 신나는 댄스 가요 모음집        NaN           NaN              NaN
# ２８１４                      NaN           NaN              NaN
# ����� ���                 NaN           NaN              NaN
# 🧡YUNG H !💜 (@yunghbrand)  NaN           NaN              NaN
# 🧿RCCJAY🧿                  NaN           NaN              NaN
#
#                           Year of Reference  Usage Period  \
# 0.0                                   216.0           NaN
# 1.0                                   220.0           NaN
# ...

# %%
sample_data_subset = sample_data[['Streams', 'Recording Artist', 'Recording Title', 'Recording Label']]
sample_data_subset
# Out:
#          Streams        Recording Artist  \
# 0             5   Bachata & Merengue Mix
# 1         8,133                   x0o0x_
# 2         5,839           Quentin Miller
# 3         7,842                       NF
# 4        28,419                   2worth
# ...          ...                     ...
# 89710    28,549                     Myuk
# 89711    28,941                     yama
# 89712    28,941                     yama
# 89713     8,970                     yama
# 89714    11,245                Lexie Liu
#
#                                Recording Title         Recording Label
# 0       No dudes de mi- Merengue & Bachata Mix                 Orchard
# 1                                       ______                  x0o0x_
# 2                             _A_ (feat. Pe$o)         1317 Recordings
# 3                                  -Interlude-           NF Real Music
# 4                          ¡!gu4na:D////:>_<^^            die happy <3
# ...
